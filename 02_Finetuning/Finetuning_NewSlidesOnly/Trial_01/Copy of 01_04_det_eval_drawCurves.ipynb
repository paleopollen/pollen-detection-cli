# %%
from google.colab import drive
# drive.flush_and_unmount()
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sys
sys.path.append('/content/gdrive/MyDrive/UTRECHT/eval_utils')
sys.path.insert(0,'/content/gdrive/MyDrive/UTRECHT/eval_utils')

# %%
import _init_paths
from utils import *
from Evaluator import *
from BoundingBox import BoundingBox
from BoundingBoxes import BoundingBoxes

# %%
trial = 'Trial_03'

eval_dir = '/content/gdrive/MyDrive/eval/01_Generalized_Model_FullTrainingData'  # location from which to read detection and ground-truth txt files
eval_dir = os.path.join(eval_dir, trial)

detections_dir = os.path.join(eval_dir, 'det2')
gt_dir = os.path.join(eval_dir, 'gt2')

save_path = os.path.join(eval_dir,'results2')         # location to save results txt file and PR-curve figure
if not os.path.exists(save_path): 
    os.makedirs(save_path)

print(gt_dir)
print(detections_dir)
print(save_path)
# Out:
# /content/gdrive/MyDrive/eval/01_Generalized_Model_FullTrainingData/Trial_03/gt2
# /content/gdrive/MyDrive/eval/01_Generalized_Model_FullTrainingData/Trial_03/det2
# /content/gdrive/MyDrive/eval/01_Generalized_Model_FullTrainingData/Trial_03/results2

# %%
# %run /content/gdrive/MyDrive/UTRECHT/eval_utils/pascalvoc.py -gt /content/gdrive/MyDrive/eval/01_Generalized_Model_FullTrainingData/Trial_03/gt2 -det /content/gdrive/MyDrive/eval/01_Generalized_Model_FullTrainingData/Trial_03/det2 -t 0.3 -detformat xyrb -gtformat xyrb -sp /content/gdrive/MyDrive/eval/01_Generalized_Model_FullTrainingData/Trial_03/results2
