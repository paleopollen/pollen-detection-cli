# %%
from google.colab import drive
# drive.flush_and_unmount()
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sys
sys.path.append('/content/gdrive/MyDrive/UTRECHT/eval_utils')
sys.path.insert(0,'/content/gdrive/MyDrive/UTRECHT/eval_utils')

# %%
import _init_paths
from utils import *
from Evaluator import *
from BoundingBox import BoundingBox
from BoundingBoxes import BoundingBoxes

# %%
project_name = 'Finetuning_allSlides'
trial = 'Trial_02' 

# save_dir = '/content/gdrive/MyDrive/UTRECHT/eval_utils'

eval_dir = '/content/gdrive/MyDrive/ENSO_project/02_det/eval' 
eval_dir = os.path.join(eval_dir, project_name, trial) 

detections_dir = os.path.join(eval_dir, 'det')
gt_dir = os.path.join(eval_dir, 'gt')

save_path = os.path.join(eval_dir , 'test_set_eval2')
if not os.path.exists(save_path): 
    os.makedirs(save_path)

print(gt_dir)
print(detections_dir)
print(save_path)
# print(save_path)
# Out:
# /content/gdrive/MyDrive/ENSO_project/02_det/eval/Finetuning_allSlides/Trial_02/gt
# /content/gdrive/MyDrive/ENSO_project/02_det/eval/Finetuning_allSlides/Trial_02/det
# /content/gdrive/MyDrive/ENSO_project/02_det/eval/Finetuning_allSlides/Trial_02/test_set_eval2

# %%
# %run /content/gdrive/MyDrive/UTRECHT/eval_utils/pascalvoc.py -gt /content/gdrive/MyDrive/ENSO_project/02_det/eval/Finetuning_allSlides/Trial_02/gt -det /content/gdrive/MyDrive/ENSO_project/02_det/eval/Finetuning_allSlides/Trial_02/det -t 0.3 -detformat xyrb -gtformat xyrb -sp /content/gdrive/MyDrive/ENSO_project/02_det/eval/Finetuning_allSlides/Trial_02/test_set_eval2
# Out:
# ####################################################################################################
# #                                                                                                  #
# # THE CURRENT VERSION WAS UPDATED WITH A VISUAL INTERFACE, INCLUDING MORE METRICS AND SUPPORTING   #
# # OTHER FILE FORMATS.                                                                              #
# #                                                                                                  #
# # PLEASE ACCESS IT ACCESSED AT:                                                                    #
# # https://github.com/rafaelpadilla/review_object_detection_metrics                                 #
# #                                                                                                  #
# # @Article{electronics10030279,                                                                    #
# ...
